# %% [markdown]
# # MSDS 430 Module 1 Python Assignment

# %% [markdown]
# #### Complete the following exercises and submit your notebook (ipynb file) to Canvas as ipynb and as html. Your file should include all output, i.e. run each cell and save your file before submitting.  In this course you should use python 3.0+ or 2.7.  I have had some load problems using Windows 10 recently with 3.7 so you may want to install both 3.7 and 2.7.

# %%
# Anything that starts with 'hash' symbol are considered as comments and not executed.
# Run the codes in this current cell. The three lines are defining three variables, the first one a string, and next two
# are numerals, one an integer and the next one is a floating point numeral. 
# Python defined variables are global and hence can be recalled later on in any other cell
f = 'first' # this is a string, assigned to f
x1 = 5      # this is an integer numeric value, assigned to x1
x2 = 4.3    # this is a numeric value, assigned x2
x3 = True   # this is a boolean value, assigned to x3
x4=0        # this is a zero value and not a null value, assigned to x4
x5=None     # this is a Null in python and has nothing defined in the named place of x5.
# all the above defined variables can be used later on in the iPython notebook
# if you want to check the data type of these you can use type(variable)

# %% [markdown]
# Problem 1 : Why the following print statement, print 'This is my first Python print execution' does not work.  How will you fix it?

# %%
print('This is my first Python print execution.') # just needed parenthesis around the text
# Out:
# This is my first Python print execution.

# %%
# Execute the command below as is, and explain what {} has achieved in the output.
# Also we are seeing for the first time .format, an object of print. Objects are methods applicable to a parent function.
# For more details about powerful print options to play with see: https://realpython.com/python-f-strings/ 
# Note that you are using the variables f, x1, x2 defined(executed) from the above cell

print("This is my {}! print execution using format value stored in a variable, and it is {}!".format(f,x2))

# check what happens when x2 is replaced by x5 vs. x2 is not replaced at all, as a curious play.

# the {} above have indicated to the kernel that the variables in the format() call later will replace the two 
#    curly braces above with the indicated two variables and output as text (aka a string)
# Out:
# This is my first! print execution using format value stored in a variable, and it is 4.3!

# %% [markdown]
# Problem 3: If you want to insert a cell below and move to that cell, what is the keyboard command? What is the keyboard command for executing the cell?
#
# Note that all keyboard commands are decipherable by clicking on the keyboard icon below 'help'.

# %%
# the B command will insert a new cell and move to it
# control+enter will execute the commands in a cell

# %% [markdown]
# Problem 4: List the top five keyboard commands you think are useful to speed up your iPython notebook execution

# %%
tab  #for autocomplete
shift+enter  #to run the selected cell
shift+tab  #to remind me how what I'm working on is supposed to work
control+/  #to comment out a line
control+s  #to save and for paranoia

# %% [markdown]
# Problem 5: Within an iPython notebook, how will you get help on any Python command?

# %%
shift+tab to bring up the tooltip

# %% [markdown]
# Problem 6: What are the top 5 magic commands that you feel are useful to interact with your operating system or Python execution?

# %%
control+c # copy
control+v # paste, indespensible
control+s # to save
tab # to switch between fields, useful when filling out any kind of forms, especially on websites
control+f # to find within a document, useful to skip to the recipe on a blog or the part you really want in a document

# %% [markdown]
# Problem 7: From the interactive interpreter (also called the terminal or command prompt on a Mac or command prompt on Windows) on your computer, find the product of any two numbers. Take a screenshot and insert your screenshot in the cell below.

# %%
from IPython.display import Image
Image("cmd screenshot.jpg")

# %% [markdown]
# Problem 8: How to get get help about any command using "tab".
# Insert a cell below and write the notes on how to do this.

# %% [markdown]
# I think this is referring to the shift+tab keyboard shortcut that brings up documentation info about the function that you use it within. For example if you put your cursor in the parenthesis in the `print()` function, it brings up what arguments the function is looking for and other useful information.

# %%
print()

# %% [markdown]
# Problem 9: Open Anaconda Navigator on your computer and take a screenshot. Insert your screenshot in the cell below.

# %%
Image("anaconda screenshot.jpg")

# %% [markdown]
# Problem 10: From Anaconda, open Spyder. In the iPython console (lower right), find the sum of any two numbers. Take a screenshot and insert your screenshot in the cell below.

# %%
Image("spyder screenshot.jpg")
